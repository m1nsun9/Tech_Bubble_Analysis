# %%
import json
import requests
import sys

# %%
base_url = "https://api.twitch.tv/kraken/search/streams?query= "
accept = "application/vnd.twitchtv.v5+json"
#authorization = "Bearer qojzpffv8q2ux1rhakaxx08rr1lvb5"
client_id = "gp762nuuoqcoxypju8c569th9wz7q5"  

headers = {"Client-Id": client_id, "Accept": accept}

# %%
response = requests.get(base_url, headers=headers)

print_json = json.dumps(response.json()["streams"], indent=4)
print(print_json)
# Out:
# [
#     {
#         "_id": 39559064893,
#         "game": "Just Chatting",
#         "broadcast_platform": "live",
#         "community_id": "",
#         "community_ids": [],
#         "viewers": 169972,
#         "video_height": 720,
#         "average_fps": 60,
#         "delay": 0,
#         "created_at": "2020-10-21T00:33:11Z",
#         "is_playlist": false,
#         "stream_type": "live",
#         "preview": {
#             "small": "https://static-cdn.jtvnw.net/previews-ttv/live_user_aoc-80x45.jpg",
#             "medium": "https://static-cdn.jtvnw.net/previews-ttv/live_user_aoc-320x180.jpg",
#             "large": "https://static-cdn.jtvnw.net/previews-ttv/live_user_aoc-640x360.jpg",
#             "template": "https://static-cdn.jtvnw.net/previews-ttv/live_user_aoc-{width}x{height}.jpg"
#         },
#         "channel": {
#             "mature": false,
#             "status": "",
#             "broadcaster_language": "en",
# ...
